# %%
from pomegranate import *

# Define the conditional probability distributions (CPDs)
guest = DiscreteDistribution({'A': 1/3, 'B': 1/3, 'C': 1/3})
prize = DiscreteDistribution({'A': 1/3, 'B': 1/3, 'C': 1/3})
monty = ConditionalProbabilityTable(
    [[ 'A', 'A', 'A', 0.0 ],
     [ 'A', 'A', 'B', 0.5 ],
     [ 'A', 'A', 'C', 0.5 ],
     [ 'A', 'B', 'A', 0.0 ],
     [ 'A', 'B', 'B', 0.0 ],
     [ 'A', 'B', 'C', 1.0 ],
     [ 'A', 'C', 'A', 0.0 ],
     [ 'A', 'C', 'B', 1.0 ],
     [ 'A', 'C', 'C', 0.0 ],
     [ 'B', 'A', 'A', 0.0 ],
     [ 'B', 'A', 'B', 0.0 ],
     [ 'B', 'A', 'C', 1.0 ],
     [ 'B', 'B', 'A', 0.5 ],
     [ 'B', 'B', 'B', 0.0 ],
     [ 'B', 'B', 'C', 0.5 ],
     [ 'B', 'C', 'A', 1.0 ],
     [ 'B', 'C', 'B', 0.0 ],
     [ 'B', 'C', 'C', 0.0 ],
     [ 'C', 'A', 'A', 0.0 ],
     [ 'C', 'A', 'B', 1.0 ],
     [ 'C', 'A', 'C', 0.0 ],
     [ 'C', 'B', 'A', 1.0 ],
     [ 'C', 'B', 'B', 0.0 ],
     [ 'C', 'B', 'C', 0.0 ],
     [ 'C', 'C', 'A', 0.5 ],
     [ 'C', 'C', 'B', 0.5 ],
     [ 'C', 'C', 'C', 0.0 ]], [guest, prize])

# Define the states for the Bayesian network
s1 = State(guest, name="guest")
s2 = State(prize, name="prize")
s3 = State(monty, name="monty")

# Create the Bayesian network
network = BayesianNetwork("Monty Hall Problem")
network.add_states(s1, s2, s3)
network.add_edge(s1, s3)
network.add_edge(s2, s3)
network.bake()

# Define the evidence
evidence = {'guest': 'A'}

# Calculate the posterior probability
beliefs = network.predict_proba(evidence)
print(beliefs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from pomegranate import *
#       3 # Define the conditional probability distributions (CPDs)
# ----> 4 guest = DiscreteDistribution({'A': 1/3, 'B': 1/3, 'C': 1/3})
#       5 prize = DiscreteDistribution({'A': 1/3, 'B': 1/3, 'C': 1/3})
#       6 monty = ConditionalProbabilityTable(
#       7     [[ 'A', 'A', 'A', 0.0 ],
#       8      [ 'A', 'A', 'B', 0.5 ],
#    (...)
#      32      [ 'C', 'C', 'B', 0.5 ],
#      33      [ 'C', 'C', 'C', 0.0 ]], [guest, prize])
#
# NameError: name 'DiscreteDistribution' is not defined

# %%
! pip install pomegranate
# Out:
# Collecting pomegranate
#   Downloading pomegranate-1.0.3-py3-none-any.whl.metadata (479 bytes)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pomegranate) (1.22.4)
# Requirement already satisfied: scipy>=1.6.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pomegranate) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pomegranate) (1.2.2)
# Requirement already satisfied: torch>=1.9.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pomegranate) (2.0.1)
# Collecting apricot-select>=0.6.1 (from pomegranate)
#   Downloading apricot-select-0.6.1.tar.gz (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: networkx>=2.8.4 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pomegranate) (3.1)
# Collecting numba>=0.43.0 (from apricot-select>=0.6.1->pomegranate)
#   Downloading numba-0.59.0-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: tqdm>=4.24.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from apricot-select>=0.6.1->pomegranate) (4.66.2)
# Collecting nose (from apricot-select>=0.6.1->pomegranate)
#   Downloading nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from scikit-learn>=1.0.2->pomegranate) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from scikit-learn>=1.0.2->pomegranate) (3.2.0)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch>=1.9.0->pomegranate) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch>=1.9.0->pomegranate) (4.9.0)
# Requirement already satisfied: sympy in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch>=1.9.0->pomegranate) (1.12)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch>=1.9.0->pomegranate) (3.1.3)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba>=0.43.0->apricot-select>=0.6.1->pomegranate)
#   Downloading llvmlite-0.42.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from tqdm>=4.24.0->apricot-select>=0.6.1->pomegranate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from jinja2->torch>=1.9.0->pomegranate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from sympy->torch>=1.9.0->pomegranate) (1.3.0)
# Downloading pomegranate-1.0.3-py3-none-any.whl (90 kB)
#    ---------------------------------------- 0.0/90.8 kB ? eta -:--:--
#    ---------------------------------------- 90.8/90.8 kB 1.7 MB/s eta 0:00:00
# Downloading numba-0.59.0-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 16.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.7 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 24.4 MB/s eta 0:00:00
# Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#    ---------------------------------------- 0.0/154.7 kB ? eta -:--:--
#    ---------------------------------------- 154.7/154.7 kB 9.0 MB/s eta 0:00:00
# Downloading llvmlite-0.42.0-cp310-cp310-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.4/28.1 MB 30.1 MB/s eta 0:00:01
#    --- ------------------------------------ 2.1/28.1 MB 45.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 3.2/28.1 MB 28.8 MB/s eta 0:00:01
#    ------ --------------------------------- 4.3/28.1 MB 27.7 MB/s eta 0:00:01
#    -------- ------------------------------- 6.2/28.1 MB 30.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 7.5/28.1 MB 31.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 8.0/28.1 MB 28.3 MB/s eta 0:00:01
#    ------------- -------------------------- 9.6/28.1 MB 29.2 MB/s eta 0:00:01
#    --------------- ------------------------ 10.8/28.1 MB 29.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 11.6/28.1 MB 27.3 MB/s eta 0:00:01
#    ------------------ --------------------- 12.7/28.1 MB 29.7 MB/s eta 0:00:01
#    -------------------- ------------------- 14.2/28.1 MB 31.2 MB/s eta 0:00:01
#    --------------------- ------------------ 15.2/28.1 MB 28.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 16.6/28.1 MB 28.5 MB/s eta 0:00:01
#    ------------------------- -------------- 18.2/28.1 MB 31.2 MB/s eta 0:00:01
#    -------------------------- ------------- 18.9/28.1 MB 28.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 20.5/28.1 MB 29.7 MB/s eta 0:00:01
#    ------------------------------- -------- 21.9/28.1 MB 31.2 MB/s eta 0:00:01
#    --------------------------------- ------ 23.2/28.1 MB 31.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.7/28.1 MB 31.1 MB/s eta 0:00:01
#    ------------------------------------ --- 25.8/28.1 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  27.6/28.1 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  28.1/28.1 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 27.3 MB/s eta 0:00:00
# Building wheels for collected packages: apricot-select
#   Building wheel for apricot-select (setup.py): started
#   Building wheel for apricot-select (setup.py): finished with status 'done'
#   Created wheel for apricot-select: filename=apricot_select-0.6.1-py3-none-any.whl size=48772 sha256=460cd64a2a64accb8b3bf99980d29aa5bf7dee1a9ebb048c3c15bedb6f79397e
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\df\d8\f9\4d62b7272bff772a126a52e507212c2fd33c0b8416d9389665
# Successfully built apricot-select
# Installing collected packages: nose, llvmlite, numba, apricot-select, pomegranate
# Successfully installed apricot-select-0.6.1 llvmlite-0.42.0 nose-1.3.7 numba-0.59.0 pomegranate-1.0.3
