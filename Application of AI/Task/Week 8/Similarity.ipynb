# %%
# !pip install rouge-score

# %% [markdown]
# # Week 4

# %%
import json
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from rouge_score import rouge_scorer

# Load JSON data from file
with open('output_week4.json', 'r') as f:
    output_week4 = json.load(f)

# Extract predicted answers and original responses
predicted_answers = [item["predicted_answer"] for item in output_week4]
original_responses = [item["original_response"] for item in output_week4]

# Initialize TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = vectorizer.fit_transform(predicted_answers + original_responses)

# Calculate cosine similarity
cos_sim = cosine_similarity(tfidf_matrix[:len(predicted_answers)], tfidf_matrix[len(predicted_answers):])

# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

# Compute ROUGE scores
rouge_scores = []
for predicted, original in zip(predicted_answers, original_responses):
    scores = scorer.score(predicted, original)
    rouge_scores.append(scores['rougeL'].fmeasure)

# Create DataFrame
data = []
for i, item in enumerate(output_week4):
    data.append({
        "question": item["question"],
        "image_path": item["image_path"],
        "predicted_answer": item["predicted_answer"],
        "original_response": item["original_response"],
        "cosine_similarity": cos_sim[i][0],
        "rouge_score": rouge_scores[i]
    })

df = pd.DataFrame(data)

# Overall performance
overall_cosine_similarity = df['cosine_similarity'].mean()
overall_rouge_score = df['rouge_score'].mean()

# Display DataFrame
print("DataFrame:")
df
# Out:
# DataFrame:
#                                                question  \
# 0      What topic will be discussed in today's lecture?
# 1     Can you provide more details about the logisti...
# 2     What other topics besides logistic regression ...
# 3     Can you summarize what will be covered in toda...
# 4     Can you provide an overview of the logistic re...
# ...                                                 ...
# 1056  What does it mean for the regression line to '...
# 1057  What are the implications of a high value for ...
# 1058  How does the algorithm handle outliers in the ...
# 1059  What is the significance of the term 'sum of s...
# 1060  How is the goodness-of-fit of the regression l...
#
#                        image_path  \
# 0     Week_4/week_04_page_001.png
# 1     Week_4/week_04_page_001.png
# 2     Week_4/week_04_page_001.png
# 3     Week_4/week_04_page_001.png
# 4     Week_4/week_04_page_001.png
# ...                           ...
# 1056  Week_4/week_04_page_054.png
# 1057  Week_4/week_04_page_054.png
# 1058  Week_4/week_04_page_054.png
# 1059  Week_4/week_04_page_054.png
# 1060  Week_4/week_04_page_054.png
#
#                                        predicted_answer  \
# 0     Today's lecture will discuss the Logistic Regr...
# 1     Logistic regression is a classification algori...
# 2          The lecture will also cover 'Least Squares'.
# 3     Today's lecture will cover the Logistic Regres...
# 4     Logistic regression is a classification algori...
# ...                                                 ...
# 1056  It means the line best represents the relation...
# 1057  A high value indicates the model is not fittin...
# 1058  The algorithm can be sensitive to outliers, wh...
# 1059  It measures the difference between observed an...
# 1060  The goodness-of-fit is assessed using metrics ...
#
#                                       original_response  cosine_similarity  \
# 0     Today's lecture will focus on the logistic reg...           0.463994
# 1     Today's lecture will delve into the logistic r...           0.096111
# 2     Besides logistic regression, the lecture may c...           0.278334
# 3     Today's lecture will primarily focus on the lo...           0.448147
# 4     The logistic regression model is a statistical...           0.096111
# ...                                                 ...                ...
# 1056  For the regression line to 'fit' the observed ...           0.064543
# 1057  A high value for the object function in the al...           0.039475
# 1058  The algorithm may be sensitive to outliers in ...           0.027117
# 1059  The term 'sum of squared errors' in the algori...           0.027238
# 1060  The goodness-of-fit of the regression line is ...           0.031194
#
#       rouge_score
# 0        0.666667
# 1        0.117647
# 2        0.272727
# 3        0.529412
# 4        0.454545
# ...           ...
# 1056     0.271186
# 1057     0.382353
# 1058     0.388060
# 1059     0.260870
# 1060     0.260870
#
# [1061 rows x 6 columns]

# %%
print("\nOverall Performance:")
print(f"Mean Cosine Similarity: {overall_cosine_similarity}")
print(f"Mean ROUGE Score: {overall_rouge_score}")
# Out:
# Overall Performance:
# Mean Cosine Similarity: 0.04330439472549059
# Mean ROUGE Score: 0.39135742352837255

# %% [markdown]
# # Week 3

# %%
import json
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from rouge_score import rouge_scorer

# Load JSON data from file
with open('output_week3.json', 'r') as f:
    output_week4 = json.load(f)

# Extract predicted answers and original responses
predicted_answers = [item["predicted_answer"] for item in output_week4]
original_responses = [item["original_response"] for item in output_week4]

# Initialize TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the text data
tfidf_matrix = vectorizer.fit_transform(predicted_answers + original_responses)

# Calculate cosine similarity
cos_sim = cosine_similarity(tfidf_matrix[:len(predicted_answers)], tfidf_matrix[len(predicted_answers):])

# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

# Compute ROUGE scores
rouge_scores = []
for predicted, original in zip(predicted_answers, original_responses):
    scores = scorer.score(predicted, original)
    rouge_scores.append(scores['rougeL'].fmeasure)

# Create DataFrame
data = []
for i, item in enumerate(output_week4):
    data.append({
        "question": item["question"],
        "image_path": item["image_path"],
        "predicted_answer": item["predicted_answer"],
        "original_response": item["original_response"],
        "cosine_similarity": cos_sim[i][0],
        "rouge_score": rouge_scores[i]
    })

df = pd.DataFrame(data)

# Overall performance
overall_cosine_similarity = df['cosine_similarity'].mean()
overall_rouge_score = df['rouge_score'].mean()

# Display DataFrame
print("DataFrame:")
df
# Out:
# DataFrame:
#                                                question  \
# 0                What is the definition of probability?
# 1     How is the probability of an event calculated ...
# 2     Can you provide an example of an unbiased proc...
# 3     How is a normal distribution used in modeling ...
# 4     What does the term 'relative frequency' mean i...
# ...                                                 ...
# 1225               Is there such thing as a true story?
# 1226       Is there a difference between true or false?
# 1227  Is there a question about how to change your c...
# 1228  Is there a way to change your classification p...
# 1229    Is there a problem in classification problem 3?
#
#                        image_path  \
# 0     Week_3/week_03_page_002.png
# 1     Week_3/week_03_page_002.png
# 2     Week_3/week_03_page_002.png
# 3     Week_3/week_03_page_002.png
# 4     Week_3/week_03_page_002.png
# ...                           ...
# 1225  Week_3/week_03_page_116.png
# 1226  Week_3/week_03_page_116.png
# 1227  Week_3/week_03_page_116.png
# 1228  Week_3/week_03_page_116.png
# 1229  Week_3/week_03_page_116.png
#
#                                        predicted_answer  \
# 0     Probability is the likelihood of an event occu...
# 1     In an actual repeated experiment, the probabil...
# 2     An unbiased process is rolling a fair six-side...
# 3     A normal distribution is used to represent the...
# 4     Relative frequency refers to the ratio of the ...
# ...                                                 ...
# 1225  Yes, there are true stories, but they are ofte...
# 1226  Yes, there's a difference. The slide mentions ...
# 1227  Yes, there's a question about how to change a ...
# 1228  Yes, you can change your classification proble...
# 1229  Yes, the problem is to change a classification...
#
#                                       original_response  cosine_similarity  \
# 0     Probability is defined as the relative frequen...           0.186224
# 1     In an actual repeated experiment, such as reca...           0.318012
# 2     An example of an unbiased process where probab...           0.117623
# 3     A normal distribution is chosen to model proba...           0.167038
# 4     Relative frequency refers to the proportion of...           0.336442
# ...                                                 ...                ...
# 1225                                                              0.000000
# 1226                                                              0.043174
# 1227  we'll have another homework 3 for this week. T...           0.000000
# 1228  we'll have another homework 3 for this week. T...           0.000000
# 1229  we'll have another homework 3 for this week. T...           0.024118
#
#       rouge_score
# 0        0.272727
# 1        0.531250
# 2        0.417910
# 3        0.392157
# 4        0.500000
# ...           ...
# 1225     0.000000
# 1226     0.000000
# 1227     0.139241
# 1228     0.104575
# 1229     0.103226
#
# [1230 rows x 6 columns]

# %%
print("\nOverall Performance:")
print(f"Mean Cosine Similarity: {overall_cosine_similarity}")
print(f"Mean ROUGE Score: {overall_rouge_score}")
# Out:
# Overall Performance:
# Mean Cosine Similarity: 0.05048834765157943
# Mean ROUGE Score: 0.29974764557593814
