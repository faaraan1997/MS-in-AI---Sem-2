# %%
! pip install git+https://github.com/ramsrigouthamg/Questgen.ai
! pip install git+https://github.com/boudinfl/pke.git

! python -m nltk.downloader universal_tagset
! python -m spacy download en
# Out:
# Collecting git+https://github.com/ramsrigouthamg/Questgen.ai
#   Cloning https://github.com/ramsrigouthamg/Questgen.ai to c:\users\dell\appdata\local\temp\pip-req-build-984db2h6
#   Resolved https://github.com/ramsrigouthamg/Questgen.ai to commit edf8f6aa6c1ad5e803ce2b6adfac8825a3e5a553
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch==2.0.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (2.0.1)
# Requirement already satisfied: transformers==4.29.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (4.29.2)
# Requirement already satisfied: sense2vec==2.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (2.0.2)
# Requirement already satisfied: strsim==0.0.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (0.0.3)
# Requirement already satisfied: six==1.16.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.16.0)
# Requirement already satisfied: networkx==3.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (3.1)
# Requirement already satisfied: numpy==1.22.4 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.22.4)
# Requirement already satisfied: scipy==1.10.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.10.1)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.2.2)
# Requirement already satisfied: unidecode==1.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.3.0)
# Requirement already satisfied: future==0.18.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (0.18.3)
# Requirement already satisfied: joblib==1.2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.2.0)
# Requirement already satisfied: pytz==2022.7.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (2022.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (2.8.2)
# Requirement already satisfied: flashtext==2.7 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (2.7)
# Requirement already satisfied: pandas==1.5.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (1.5.3)
# Requirement already satisfied: sentencepiece==0.1.99 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from Questgen==1.0.1) (0.1.99)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from scikit-learn==1.2.2->Questgen==1.0.1) (3.2.0)
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from sense2vec==2.0.2->Questgen==1.0.1) (3.7.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.8.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from sense2vec==2.0.2->Questgen==1.0.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from sense2vec==2.0.2->Questgen==1.0.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from sense2vec==2.0.2->Questgen==1.0.1) (2.0.10)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch==2.0.1->Questgen==1.0.1) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch==2.0.1->Questgen==1.0.1) (4.9.0)
# Requirement already satisfied: sympy in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch==2.0.1->Questgen==1.0.1) (1.12)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from torch==2.0.1->Questgen==1.0.1) (3.1.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (2023.12.25)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from transformers==4.29.2->Questgen==1.0.1) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.29.2->Questgen==1.0.1) (2024.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (8.2.2)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (2.6.1)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (68.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests->transformers==4.29.2->Questgen==1.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests->transformers==4.29.2->Questgen==1.0.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests->transformers==4.29.2->Questgen==1.0.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests->transformers==4.29.2->Questgen==1.0.1) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from tqdm>=4.27->transformers==4.29.2->Questgen==1.0.1) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from jinja2->torch==2.0.1->Questgen==1.0.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from sympy->torch==2.0.1->Questgen==1.0.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (2.16.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.0.0->sense2vec==2.0.2->Questgen==1.0.1) (0.16.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/ramsrigouthamg/Questgen.ai 'C:\Users\Dell\AppData\Local\Temp\pip-req-build-984db2h6'
# Collecting git+https://github.com/boudinfl/pke.git
#   Cloning https://github.com/boudinfl/pke.git to c:\users\dell\appdata\local\temp\pip-req-build-7j0a09og
#   Resolved https://github.com/boudinfl/pke.git to commit 69871ffdb720b83df23684fea53ec8776fd87e63
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (3.8.1)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (3.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (1.22.4)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (1.10.1)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (1.2.2)
# Requirement already satisfied: unidecode in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (1.3.0)
# Requirement already satisfied: future in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (0.18.3)
# Requirement already satisfied: joblib in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (1.2.0)
# Requirement already satisfied: spacy>=3.2.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pke==2.0.0) (3.7.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (2.6.1)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy>=3.2.3->pke==2.0.0) (3.3.0)
# Requirement already satisfied: click in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from nltk->pke==2.0.0) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from nltk->pke==2.0.0) (2023.12.25)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from scikit-learn->pke==2.0.0) (3.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.2.3->pke==2.0.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.2.3->pke==2.0.0) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.2.3->pke==2.0.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.2.3->pke==2.0.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.2.3->pke==2.0.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=3.2.3->pke==2.0.0) (0.4.6)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.2.3->pke==2.0.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from jinja2->spacy>=3.2.3->pke==2.0.0) (2.1.5)
#   Running command git clone --filter=blob:none --quiet https://github.com/boudinfl/pke.git 'C:\Users\Dell\AppData\Local\Temp\pip-req-build-7j0a09og'
# c:\Users\Dell\anaconda3\envs\application_of_ai\lib\runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 487.6 kB/s eta 0:00:27
#      --------------------------------------- 0.1/12.8 MB 655.4 kB/s eta 0:00:20
#       --------------------------------------- 0.3/12.8 MB 1.7 MB/s eta 0:00:08
#      --- ------------------------------------ 1.2/12.8 MB 5.9 MB/s eta 0:00:02
#      ------- -------------------------------- 2.3/12.8 MB 9.3 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.8/12.8 MB 12.7 MB/s eta 0:00:01
#      -------------- ------------------------- 4.8/12.8 MB 14.5 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 16.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.3/12.8 MB 17.4 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 21.0 MB/s eta 0:00:01
#      ------------------------------------ -- 12.0/12.8 MB 32.8 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.1)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.22.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\application_of_ai\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from pprint import pprint
import nltk
nltk.download('stopwords')
from Questgen import main
qe= main.BoolQGen()
payload = {
            "input_text": "Sachin Ramesh Tendulkar is a former international cricketer from India and a former captain of the Indian national team. He is widely regarded as one of the greatest batsmen in the history of cricket. He is the highest run scorer of all time in International cricket."
        }
output = qe.predict_boolq(payload)
pprint (output)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'Boolean Questions': ['Is sachin ramesh tendulkar the highest run scorer in '
#                        'cricket?',
#                        'Is sachin ramesh tendulkar the highest run scorer in '
#                        'cricket?',
#                        'Is sachin ramesh tendulkar the greatest batsman in '
#                        'cricket?'],
#  'Count': 4,
#  'Text': 'Sachin Ramesh Tendulkar is a former international cricketer from '
#          'India and a former captain of the Indian national team. He is widely '
#          'regarded as one of the greatest batsmen in the history of cricket. '
#          'He is the highest run scorer of all time in International cricket.'}

# %%
output['Text']
# Out:
# 'Sachin Ramesh Tendulkar is a former international cricketer from India and a former captain of the Indian national team. He is widely regarded as one of the greatest batsmen in the history of cricket. He is the highest run scorer of all time in International cricket.'

# %%
import json
from pprint import pprint
import nltk
nltk.download('stopwords')
from Questgen import main


with open('transcript.json', 'r') as file:
    data = json.load(file)

# Create the BoolQGen object
qe = main.BoolQGen()

# Iterate over each entry in the JSON file
for entry in data:
    # Extract the transcript text from the entry
    transcript_text = entry['transcript']

    payload = {"input_text": transcript_text}
    
    # Generate output based on the payload
    output = qe.predict_boolq(payload)
    
    # Print the output
    pprint(output)

# %%
import json
from pprint import pprint
import nltk
nltk.download('stopwords')
from Questgen import main

# Load the JSON file
with open('transcript.json', 'r') as file:
    data = json.load(file)

# Create the BoolQGen object
qe = main.BoolQGen()

# Initialize a list to store Q&A data
qna_data = []

# Iterate over each entry in the JSON file
for entry in data:
    # Extract the transcript text from the entry
    transcript_text = entry['transcript']
    
    # Create a payload using the transcript text
    payload = {"input_text": transcript_text}
    
    # Generate boolean questions based on the payload
    output = qe.predict_boolq(payload)
    
    # Extract boolean questions from the output
    boolean_questions = output['Boolean Questions']
    
    # Create a Q&A dictionary for each boolean question
    for question in boolean_questions:
        qna_entry = {
            "instruction": question,
            "context": transcript_text,
            "category": "boolean_question",
            "week": entry.get("week", None),
            # Add additional fields if necessary
        }
        # Append the Q&A entry to the list
        qna_data.append(qna_entry)

# Write the Q&A data to a new JSON file
with open('QNA.json', 'w') as outfile:
    json.dump(qna_data, outfile, indent=4)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
